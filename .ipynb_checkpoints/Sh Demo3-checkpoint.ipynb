# %%
from sh import git, ls, sort, wc, ls, tail, head

# %%
tdir="/Users/kutenai/Downloads"
ls(tdir)
# Out:
# $RECYCLE.BIN
# 1Password-4.5.6.xpi
# 83802031_3.DOC
# AdobeReader_dc_en_a_install.dmg
# Aldryn Desktop (1).dmg
# Aldryn Desktop.dmg
# Alfred_3.0.3_694.dmg
# Annotated code for Tealium tagging changes.docx
# Arduino.app
# AspenCore - Site Traffic - 52 weeks-1.pptx
# AspenCore - Site Traffic - 52 weeks.pptx
# Astropad.app
# Astropad.zip
# Balsamiq_Mockups_3.3.14.dmg
# CA_Mac_Download.dmg
# CHANNEL API DOCUMENTATION V0.1.docx
# CS4_Download.dmg
# CraftInstaller (1).zip
# CraftInstaller (2).zip
# CraftInstaller (3).zip
# CraftInstaller.1.app
# CraftInstaller.app
# CraftInstaller.zip
# D3-Tips-and-Tricks.pdf
# DEVONthink_Pro.dmg
# Design Tools Update PR_DRAFT.DOC
# Discord.dmg
# DisplayLink USB Graphics Software for Mac OS X 2.5.1.dmg
# DisplayLink_Mac_OS_X_2.5.dmg
# Docker.dmg
# DockerToolbox-1.10.2.pkg
# DockerToolbox-1.10.3.pkg
# DockerToolbox-1.11.0.exe
# DockerToolbox-1.11.0.pkg
# DockerToolbox-1.11.1.pkg
# Docker_bash 2.sh
# Docker_bash.sh
# Ed Henderson 2016 Fall Friday-7pm-1.xlsx
# ...

# %%
sort(ls(tdir), "-r")
# Out:
# wallaby-intellij-v1.0.53.zip
# vlc-2.2.4.dmg
# tmux-2.2.tar.gz
# startbootstrap-clean-blog-1.0.4.zip
# startbootstrap-clean-blog-1.0.4 (1).zip
# slingtv.dmg
# slingtv (1).dmg
# sketch.zip
# schematics_users.xls
# python-3.5.1-macosx10.6.pkg
# python-2.7.11-macosx10.6.pkg
# pymakr_1.0.0.b1.dmg
# pycharm-professional-5.0.4-jdk-bundled.dmg
# pycharm-professional-2016.2.dmg
# pycharm-professional-2016.2.2.dmg
# pycharm-professional-2016.1.dmg
# postgresql-9.5.2-1-osx.dmg
# pb_mime_attachment.png
# papers_342_439.dmg
# openmv-ide-mac-1.0.0.dmg
# opencv-2.4.13.zip
# on-time-performance.zip
# node-v6.2.1.pkg
# node-v6.2.0.pkg
# node-v6.0.0.pkg
# node-v5.7.0.pkg
# navicat112_premium_en.dmg
# mysql-5.7.11-osx10.10-x86_64.dmg
# mBlock_mac_v3.2.2.zip
# logstash-2.3.3.tar.gz
# lion.jpeg
# libevent-2.0.22-stable.tar.gz
# lcc3.9.3.zip
# keyboardmaestro-703.zip
# jdk-8u91-macosx-x64.dmg
# irccloud-0.1.9.dmg
# iot-arduino.git
# invoice.20638242-0.pdf
# install_advance_5.00.03.exe
# ...

# %%
head(sort(ls(tdir)))
# Out:
# $RECYCLE.BIN
# Arduino.app
# Astropad.app
# CraftInstaller.1.app
# CraftInstaller.app
# LCC Installer.app
# Lato2OFL
# Tower.app
# bebas-neue.zip Folder
# bootstrap-4.0.0-alpha.3

# %%
sort(tail(sort(ls(tdir), "-r")))
# Out:
# $RECYCLE.BIN
# Arduino.app
# Astropad.app
# CraftInstaller.1.app
# CraftInstaller.app
# LCC Installer.app
# Lato2OFL
# Tower.app
# bebas-neue.zip Folder
# bootstrap-4.0.0-alpha.3

# %%
if sort(tail(sort(ls(tdir), "-r"))) == head(sort(ls(tdir))):
    print("Boo Ya!")
# Out:
# Boo Ya!
